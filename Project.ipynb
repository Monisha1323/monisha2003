# %%
#1. create a dataframe
import pandas as pd
df=pd.read_csv('/content/indian-cities-dataset.csv')
df
# Out:
#             Origin  Destination  Distance
# 0             Agra        Delhi       240
# 1             Agra      Lucknow       334
# 2             Agra       Kanpur       277
# 3        Ahmedabad       Mumbai       526
# 4        Ahmedabad         Pune       663
# ..             ...          ...       ...
# 78        Varanasi      Kolkata       683
# 79        Varanasi      Lucknow       312
# 80  Vishakhapatnam  Bhubaneswar       441
# 81  Vishakhapatnam    Hyderabad       618
# 82  Vishakhapatnam      Kolkata       882
#
# [83 rows x 3 columns]

# %%
#1.preprocessing
df.shape
# Out:
# (83, 3)

# %%
df.size
# Out:
# 249

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Origin       83 non-null     object
#  1   Destination  83 non-null     object
#  2   Distance     83 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#           Distance
# count    83.000000
# mean    710.542169
# std     478.655594
# min      89.000000
# 25%     345.500000
# 50%     578.000000
# 75%     799.000000
# max    2208.000000

# %%
df['Destination'].unique()
# Out:
# array(['Delhi', 'Lucknow', 'Kanpur', 'Mumbai', 'Pune', 'Jaipur',
#        'Udaipur', 'Hyderabad', 'Chennai', 'Goa', 'Kolkata',
#        'Vishakhapatnam', 'Patna', 'Bengaluru', 'Kochi', 'Agra',
#        'Thiruvananthapuram', 'Ahmedabad', 'Varanasi', 'Bhubaneswar'],
#       dtype=object)

# %%
df['Destination'].nunique()
# Out:
# 20

# %%
df['Origin'].unique()
# Out:
# array(['Agra', 'Ahmedabad', 'Bengaluru', 'Bhubaneswar', 'Chennai',
#        'Delhi', 'Goa', 'Hyderabad', 'Jaipur', 'Kanpur', 'Kochi',
#        'Kolkata', 'Lucknow', 'Mumbai', 'Patna', 'Pune', 'Udaipur',
#        'Varanasi', 'Vishakhapatnam'], dtype=object)

# %%
df['Origin'].nunique()
# Out:
# 19

# %%
df['Distance'].unique()
# Out:
# array([ 240,  334,  277,  526,  663,  660,  258,  839,  576,  346,  562,
#         442,  444,  831,  626,  345,  690, 1335, 1666,  307,  243,  548,
#        2208, 2174, 1452, 1582,  674,  755,  585, 1305,  627,  708, 1583,
#        1489,  659,  397,  308, 1170, 1191,  301,  115,  328,  547,  754,
#         206,  680,  554, 1668, 1563,  553,  333,   89,  148, 1453,  713,
#         984, 1886, 1338,  256,  578,  150,  560,  842,  257,  767,  688,
#         259,  683,  312,  441,  618,  882])

# %%
df['Distance'].nunique()
# Out:
# 72

# %%
df['Origin'].count()
# Out:
# 83

# %%
df.isnull().sum()
# Out:
# Origin         0
# Destination    0
# Distance       0
# dtype: int64

# %%
df.nunique()
# Out:
# Origin         19
# Destination    20
# Distance       72
# dtype: int64

# %%
#3.visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Visualization 2: Box Plot of Distances by Origin
plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x='Origin', y='Distance', palette='viridis')
plt.title('Box Plot of Distances by Origin')
plt.xlabel('Origin')
plt.ylabel('Distance ')
plt.xticks(rotation=45)
plt.show()

# Visualization 3: Scatter Plot of Distances by Origin and Destination
plt.figure(figsize=(20, 16))
sns.scatterplot(data=df, x='Origin', y='Destination', hue='Distance', palette='coolwarm', size='Distance',sizes=(20, 300))
plt.title('Scatter Plot of Distances by Origin and Destination')
plt.xlabel('Origin')
plt.ylabel('Destination')
plt.legend(title='Distance', bbox_to_anchor=(1, 1))
plt.show()

# %%
#divide input and outputx
x=df.iloc[:,0:2].values
x
# Out:
# array([['Agra', 'Delhi'],
#        ['Agra', 'Lucknow'],
#        ['Agra', 'Kanpur'],
#        ['Ahmedabad', 'Mumbai'],
#        ['Ahmedabad', 'Pune'],
#        ['Ahmedabad', 'Jaipur'],
#        ['Ahmedabad', 'Udaipur'],
#        ['Bengaluru', 'Pune'],
#        ['Bengaluru', 'Hyderabad'],
#        ['Bengaluru', 'Chennai'],
#        ['Bengaluru', 'Goa'],
#        ['Bhubaneswar', 'Kolkata'],
#        ['Bhubaneswar', 'Vishakhapatnam'],
#        ['Bhubaneswar', 'Patna'],
#        ['Chennai', 'Hyderabad'],
#        ['Chennai', 'Bengaluru'],
#        ['Chennai', 'Kochi'],
#        ['Chennai', 'Mumbai'],
#        ['Chennai', 'Kolkata'],
#        ['Delhi', 'Jaipur'],
#        ['Delhi', 'Agra'],
#        ['Delhi', 'Lucknow'],
#        ['Delhi', 'Chennai'],
#        ['Delhi', 'Bengaluru'],
#        ['Delhi', 'Mumbai'],
#        ['Delhi', 'Hyderabad'],
#        ['Goa', 'Hyderabad'],
#        ['Goa', 'Kochi'],
#        ['Goa', 'Mumbai'],
#        ['Goa', 'Pune'],
# ...

# %%
y=df.iloc[:,2].values
y
# Out:
# array([ 240,  334,  277,  526,  663,  660,  258,  839,  576,  346,  562,
#         442,  444,  831,  626,  345,  690, 1335, 1666,  307,  243,  548,
#        2208, 2174, 1452, 1582,  674,  755,  585,  442, 1305,  562,  576,
#         627,  674,  708, 1583, 1489,  659,  397,  308, 1170, 1191,  301,
#         115,  328,  690,  547,  754,  206,  547,  680,  554,  442, 1668,
#        1563,  553,  333,   89,  148,  526, 1453,  713,  984, 1886, 1338,
#         256,  578,  150,  660,  560,  842,  257,  397,  767,  688,  328,
#         259,  683,  312,  441,  618,  882])

# %%
df['Distance']=df['Distance'].astype(float)
print(df.dtypes)
# Out:
# Origin          object
# Destination     object
# Distance       float64
# dtype: object

# %%
#5. train and test the variable
from sklearn.model_selection import train_test_split # library-train_test_split,sklearn.model_selection is package
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
print(x.shape)#100% data
print(x_train.shape)#75% data
print(x_test.shape)#25% data
# Out:
# (83, 2)
# (62, 2)
# (21, 2)

# %%
print(y.shape)#100% data
print(y_train.shape)#75% data
print(y_test.shape)#25% data
# Out:
# (83,)
# (62,)
# (21,)

# %%
#6.Normalisation
from sklearn.preprocessing import MinMaxScaler

# Assuming 'distance_km' is the feature you want to normalize
feature_to_normalize = df[['Distance']]

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the feature using Min-Max scaling
normalized_feature = scaler.fit_transform(feature_to_normalize)

# Replace the original column with the normalized values
df['normalized_distance'] = normalized_feature

# Display the normalized dataset
print(df.head())
# Out:
#       Origin Destination  Distance  normalized_distance
# 0       Agra       Delhi     240.0             0.071260
# 1       Agra     Lucknow     334.0             0.115621
# 2       Agra      Kanpur     277.0             0.088721
# 3  Ahmedabad      Mumbai     526.0             0.206229
# 4  Ahmedabad        Pune     663.0             0.270882

# %%
#7.run the regressor,classsifier or clusterer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler



# Assuming 'feature1', 'feature2', ... are your input features and 'distance_km' is the target variable
X = df[['Origin', 'Destination']]  # Adjust based on your dataset
y = df['Distance']  # Assuming 'distance_km' is your target variable

# Convert string features to float using one-hot encoding
X_encoded = pd.get_dummies(X, columns=['Origin','Destination'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize features (optional but can be beneficial for linear regression)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the Linear Regression model
model = LinearRegression()

# %%
#8. fit the model
# Train the model on the training set
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#9.predict the output
y_pred=model.predict(X_test )#using input test data,we predict
y_pred #predicted o/p values
# Out:
# array([ 467.49073248,  989.3697276 , 1488.5930989 ,  849.29491433,
#         964.90455919,  743.11800046,  514.48823983, 1017.02163486,
#         663.49601401,  463.98891899,  383.92436854, 1152.47048434,
#          19.01053328, 1064.07076377,  406.67657556,  450.31488039,
#         888.89378317])

# %%
y_test
# Out:
# 30    1305.0
# 0      240.0
# 22    2208.0
# 31     562.0
# 18    1666.0
# 28     585.0
# 10     562.0
# 53     442.0
# 4      663.0
# 12     444.0
# 49     206.0
# 33     627.0
# 69     660.0
# 35     708.0
# 70     560.0
# 45     328.0
# 75     688.0
# Name: Distance, dtype: float64

# %%
#conclusion
# we have to compare corresponding values of y_pred and y
#50 when we compare,we come to know that there is huge difference
#this huge difference does not mean,our model has predicted wrong
#it only means our model is not linear or lesslinear
#linearity of  a model depends on nature of the data
#as well as size of the data

# %%
#Tfidf vectorisation
#individual prediction

a=df['Origin'][10]
a
# Out:
# 'Bengaluru'

# %%
b=df['Destination'][10]
b
# Out:
# 'Goa'

# %%
#streamlit (web app)
#let us create our first streamlit webapp
#the streamlit library is not intalled default by google colab
#hence we have to install it manually
# !pip install streamlit --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 44.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 80.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00

# %%
# %%writefile distance.py
import streamlit as st


data = {
       'Agra-Delhi': 240,
       'Agra-Lucknow': 334,
       'Agra-Kanpur':526,
       'Ahmedabad-Mumbai':663,
       'Ahmedabad-Pune':660,
       'Ahmedabad-Jaipur':258,
       'Ahmedabad-Udaipur':839,
       'Bengaluru-Pune':576,
       'Bengaluru-Hyderabad':346,
       'Bengaluru-Chennai':562,
       'Bengaluru-Goa':442,
       'Bhubaneswar-Kolkata':444,
       'Bhubaneswar-Vishakhapatnam':831,
       'Bhubaneswar-Patna':626,
       'Chennai-Hyderabad':345,
       'Chennai-Bengaluru':690,
       'Chennai-Kochi':1335,
       'Chennai-Mumbai':1666,
       'Chennai-Kolkata':307,
       'Delhi-Jaipur':243,
       'Delhi-Agra':548,
       'Delhi-Lucknow':2208,
       'Delhi-Chennai':2174,
       'Delhi-Bengaluru':1452,
       'Delhi-Mumbai':1582,
       'Delhi-Hyderabad':674,
       'Goa-Hyderabad':755,
       'Goa-Kochi':585,
       'Goa-Mumbai':442,
       'Goa-Pune':1305,
       'Goa-Thiruvananthapuram':562,
       'Hyderabad-Pune':576,
       'Hyderabad-Bengaluru':627,
       'Hyderabad-Chennai':674,
       'Hyderabad-Goa':708,
       'Hyderabad-Mumbai':1583,
       'Hyderabad-Delhi':1489,
       'Hyderabad-Kolkata':659,
       'Jaipur-Ahmedabad':697,
       'Jaipur-Udaipur':308,
       'Jaipur-Delhi':1170,
       'Jaipur-Mumbai':1191,
       'Jaipur-Pune':301,
       'Kanpur-Agra':115,
       'Kanpur-Lucknow':328,
       'Kanpur-Varanasi':690,
       'Kochi-Chennai':547,
       'Kochi-Bengaluru':754,
       'Kochi-Goa':206,
       'Kochi-Thiruvananthapuram':547,
       'Kochi-Bengaluru':680,
       'Kolkata-Varanasi':554,
       'Kolkata-Patna':442,
       'Kolkata-Bhubaneswar':1668,
       'Kolkata-Chennai':1563,
       'Kolkata-Delhi':553,
       'Lucknow-Delhi':333,
       'Lucknow-Agra':89,
       'Lucknow-Kanpur':148,
       'Mumbai-Pune':526,
       'Mumbai-Ahmedabad':1453,
       'Mumbai-Delhi':713,
       'Mumbai-Hyderabad':984,
       'Mumbai-Bengaluru':1886,
       'Mumbai-Kolkata':1338,
       'Mumbai-Chennai':256,
       'Patna-Varanasi':578,
       'Patna-Kolkata':150,
       'Pune-Mumbai':560,
       'Pune-Ahmedabad':842,
       'Pune-Hyderabad':257,
       'Pune-Bengaluru':767,
       'Udaipur-Ahmedabad':688,
       'Udaipur-Jaipur':259,
       'Udaipur-Mumbai':683,
       'Udaipur-Delhi':312,
       'Varanasi-Kanpur':456,
       'Varanasi-Patna':683,
       'Varanasi-Kolkata':312,
       'Varanasi-Lucknow':441,
       'Vishakhapatnam-Bhubaneswar':618,
       'Vishakhapatnam-Hyderabad':882,
       'Vishakhapatnam-Kolkata':567

}

# Streamlit app
st.title('Distance Calculator App')

# Create a dropdown for origin and destination
origin = st.selectbox('Select Origin', list(set([x.split('-')[0] for x in data.keys()])))
destination = st.selectbox('Select Destination', list(set([x.split('-')[1] for x in data.keys()])))

# Display the distance
key = f'{origin}-{destination}'
if key in data:
    distance = data[key]
    st.write(f'Distance from {origin} to {destination}: {distance} km')
else:
    st.write(f'Distance from {origin} to {destination} not available')
# Out:
# Overwriting distance.py

# %%
#we have to execute distance.py using localtunnel
# !streamlit run distance.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.222.45.207:8501
#
# npx: installed 22 in 4.259s
# your url is: https://major-flowers-lick.loca.lt
