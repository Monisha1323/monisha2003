# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/Monisha1323/monisha2003/refs/heads/main/Monisha_indian-cities-dataset.csv')
df
# Out:
#             Origin  Destination  Distance
# 0             Agra        Delhi       240
# 1             Agra      Lucknow       334
# 2             Agra       Kanpur       277
# 3        Ahmedabad       Mumbai       526
# 4        Ahmedabad         Pune       663
# ..             ...          ...       ...
# 80        Varanasi      Kolkata       683
# 81        Varanasi      Lucknow       312
# 82  Vishakhapatnam  Bhubaneswar       441
# 83  Vishakhapatnam    Hyderabad       618
# 84  Vishakhapatnam      Kolkata       882
#
# [85 rows x 3 columns]

# %%
#2.pre processing
df.shape
# Out:
# (85, 3)

# %%
df.size
# Out:
# 255

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Origin       85 non-null     object
#  1   Destination  85 non-null     object
#  2   Distance     85 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#           Distance
# count    85.000000
# mean    711.600000
# std     480.512678
# min      89.000000
# 25%     345.000000
# 50%     578.000000
# 75%     831.000000
# max    2208.000000

# %%
df['Destination'].unique()
# Out:
# array(['Delhi', 'Lucknow', 'Kanpur', 'Mumbai', 'Pune', 'Jaipur',
#        'Udaipur', 'Hyderabad', 'Chennai', 'Goa', 'Kolkata',
#        'Vishakhapatnam', 'Patna', 'Bengaluru', 'Kochi', 'Agra',
#        'Thiruvananthapuram', 'Ahmedabad', 'Varanasi', 'Bhubaneswar'],
#       dtype=object)

# %%
df['Destination'].nunique()
# Out:
# 20

# %%
df['Origin'].unique()
# Out:
# array(['Agra', 'Ahmedabad', 'Bengaluru', 'Bhubaneswar', 'Chennai',
#        'Delhi', 'Goa', 'Hyderabad', 'Jaipur', 'Kanpur', 'Kochi',
#        'Kolkata', 'Lucknow', 'Mumbai', 'Patna', 'Pune', 'Udaipur',
#        'Varanasi', 'Vishakhapatnam'], dtype=object)

# %%
df['Origin'].nunique()
# Out:
# 20

# %%
df['Distance'].unique()
# Out:
# array([ 240,  334,  277,  526,  663,  660,  258,  839,  576,  346,  562,
#         442,  444,  831,  626,  345,  690, 1335, 1666,  307,  243,  548,
#        2208, 2174, 1452, 1582,  674,  755,  585, 1305,  627,  708, 1583,
#        1489,  659,  397,  308, 1170, 1191,  301,  115,  328,  547,  754,
#         206,  680,  554, 1668, 1563,  553,  333,   89,  148, 1453,  713,
#         984, 1886, 1338,  256,  578,  150,  560,  842,  257,  767,  688,
#         259,  683,  312,  441,  618,  882])

# %%
df['Distance'].nunique()
# Out:
# 72

# %%
df['Origin'].count()
# Out:
# 85

# %%
df.isnull().sum()
# Out:
# Origin         0
# Destination    0
# Distance       0
# dtype: int64

# %%
df.nunique()
# Out:
# Origin         20
# Destination    20
# Distance       72
# dtype: int64

# %%
#3.visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Visualization 2: Box Plot of Distances by Origin
plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x='Origin', y='Distance', palette='viridis')
plt.title('Box Plot of Distances by Origin')
plt.xlabel('Origin')
plt.ylabel('Distance ')
plt.xticks(rotation=45)
plt.show()

# Visualization 3: Scatter Plot of Distances by Origin and Destination
plt.figure(figsize=(20, 16))
sns.scatterplot(data=df, x='Origin', y='Destination', hue='Distance', palette='coolwarm', size='Distance', sizes=(20, 200))
plt.title('Scatter Plot of Distances by Origin and Destination')
plt.xlabel('Origin')
plt.ylabel('Destination')
plt.legend(title='Distance', bbox_to_anchor=(1, 1))
plt.show()
# Out:
# <ipython-input-21-31ecc7c2cfe1>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Origin', y='Distance', palette='viridis')

# %%
#4.divide input and outputx
x=df.iloc[:,0:2].values
x
# Out:
# array([['Agra', 'Delhi'],
#        ['Agra', 'Lucknow'],
#        ['Agra', 'Kanpur'],
#        ['Ahmedabad', 'Mumbai'],
#        ['Ahmedabad', 'Pune'],
#        ['Ahmedabad', 'Jaipur'],
#        ['Ahmedabad', 'Udaipur'],
#        ['Bengaluru', 'Pune'],
#        ['Bengaluru', 'Hyderabad'],
#        ['Bengaluru', 'Chennai'],
#        ['Bengaluru', 'Goa'],
#        ['Bhubaneswar', 'Kolkata'],
#        ['Bhubaneswar', 'Vishakhapatnam'],
#        ['Bhubaneswar', 'Patna'],
#        ['Chennai', 'Hyderabad'],
#        ['Chennai', 'Bengaluru'],
#        ['Chennai', 'Kochi'],
#        ['Chennai', 'Mumbai'],
#        ['Chennai', 'Kolkata'],
#        ['Delhi', 'Jaipur'],
#        ['Delhi', 'Agra'],
#        ['Delhi', 'Lucknow'],
#        ['Delhi', 'Chennai'],
#        ['Delhi', 'Bengaluru'],
#        ['Delhi', 'Mumbai'],
#        ['Delhi', 'Hyderabad'],
#        ['Goa', 'Hyderabad'],
#        ['Goa', 'Kochi'],
#        ['Goa', 'Mumbai'],
#        ['Goa', 'Pune'],
#        ['Goa', 'Thiruvananthapuram'],
#        ['Hyderabad', 'Pune'],
#        ['Hyderabad', 'Bengaluru'],
#        ['Hyderabad', 'Chennai'],
#        ['Hyderabad', 'Goa'],
#        ['Hyderabad', 'Mumbai'],
#        ['Hyderabad', 'Delhi'],
#        ['Hyderabad', 'Kolkata'],
#        ['Jaipur', 'Ahmedabad'],
#        ['Jaipur', 'Udaipur'],
#        ['Jaipur', 'Delhi'],
#        ['Jaipur', 'Mumbai'],
#        ['Jaipur', 'Pune'],
#        ['Kanpur', 'Agra'],
#        ['Kanpur', 'Lucknow'],
#        ['Kanpur', 'Varanasi'],
#        ['Kochi', 'Chennai'],
#        ['Kochi', 'Bengaluru'],
#        ['Kochi', 'Goa'],
#        ['Kochi', 'Thiruvananthapuram'],
#        ['Kochi', 'Bengaluru'],
#        ['Kolkata', 'Varanasi'],
#        ['Kolkata', 'Patna'],
#        ['Kolkata', 'Bhubaneswar'],
#        ['Kolkata', 'Chennai'],
#        ['Kolkata', 'Delhi'],
#        ['Lucknow', 'Delhi'],
#        ['Lucknow', 'Agra'],
#        ['Lucknow', 'Kanpur'],
#        ['Mumbai', 'Pune'],
#        ['Mumbai', 'Ahmedabad'],
#        ['Mumbai', 'Delhi'],
#        ['Mumbai', 'Hyderabad'],
#        ['Mumbai', 'Bengaluru'],
#        ['Mumbai', 'Kolkata'],
#        ['Mumbai', 'Chennai'],
#        ['Patna', 'Varanasi'],
#        ['Patna', 'Kolkata'],
#        ['Pune', 'Mumbai'],
#        ['Pune', 'Ahmedabad'],
#        ['Pune', 'Hyderabad'],
#        ['Pune', 'Bengaluru'],
#        ['Thiruvananthapuram', 'Kochi'],
#        ['Thiruvananthapuram', 'Goa'],
#        ['Udaipur', 'Ahmedabad'],
#        ['Udaipur', 'Jaipur'],
#        ['Udaipur', 'Mumbai'],
#        ['Udaipur', 'Delhi'],
#        ['Varanasi', 'Kanpur'],
#        ['Varanasi', 'Patna'],
#        ['Varanasi', 'Kolkata'],
#        ['Varanasi', 'Lucknow'],
#        ['Vishakhapatnam', 'Bhubaneswar'],
#        ['Vishakhapatnam', 'Hyderabad'],
#        ['Vishakhapatnam', 'Kolkata']], dtype=object)

# %%
y=df.iloc[:,2].values
y
# Out:
# array([ 240.,  334.,  277.,  526.,  663.,  660.,  258.,  839.,  576.,
#         346.,  562.,  442.,  444.,  831.,  626.,  345.,  690., 1335.,
#        1666.,  307.,  243.,  548., 2208., 2174., 1452., 1582.,  674.,
#         755.,  585.,  442., 1305.,  562.,  576.,  627.,  674.,  708.,
#        1583., 1489.,  659.,  397.,  308., 1170., 1191.,  301.,  115.,
#         328.,  690.,  547.,  754.,  206.,  547.,  680.,  554.,  442.,
#        1668., 1563.,  553.,  333.,   89.,  148.,  526., 1453.,  713.,
#         984., 1886., 1338.,  256.,  578.,  150.,  660.,  560.,  842.,
#         206., 1305.,  257.,  397.,  767.,  688.,  328.,  259.,  683.,
#         312.,  441.,  618.,  882.])

# %%
df['Distance']=df['Distance'].astype(float)
print(df.dtypes)
# Out:
# Origin          object
# Destination     object
# Distance       float64
# dtype: object

# %%
#5.train and test the variables
from sklearn.model_selection import train_test_split # library-train_test_split,sklearn.model_selection is package
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
print(x.shape)#100% data
print(x_train.shape)#75% data
print(x_test.shape)#25% data
# Out:
# (85, 2)
# (63, 2)
# (22, 2)

# %%
print(y.shape)#100% data
print(y_train.shape)#75% data
print(y_test.shape)#25% data
# Out:
# (85,)
# (63,)
# (22,)

# %%
#6.Normalisation
from sklearn.preprocessing import MinMaxScaler

# Assuming 'distance_km' is the feature you want to normalize
feature_to_normalize = df[['Distance']]

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the feature using Min-Max scaling
normalized_feature = scaler.fit_transform(feature_to_normalize)

# Replace the original column with the normalized values
df['normalized_distance'] = normalized_feature

# Display the normalized dataset
print(df.head())
# Out:
#       Origin Destination  Distance  normalized_distance
# 0       Agra       Delhi     240.0             0.071260
# 1       Agra     Lucknow     334.0             0.115621
# 2       Agra      Kanpur     277.0             0.088721
# 3  Ahmedabad      Mumbai     526.0             0.206229
# 4  Ahmedabad        Pune     663.0             0.270882

# %%
#7.run the regressor,classsifier or clusterer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler


# Assuming 'Origin', 'Destination', ... are your input features and 'distance_km' is the target variable
X = df[['Origin', 'Destination']]  # Adjust based on your dataset
y = df['Distance']  # Assuming 'distance_km' is your target variable

# Convert string features to float using one-hot encoding
X_encoded = pd.get_dummies(X, columns=['Origin','Destination'])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize features (optional but can be beneficial for linear regression)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the Linear Regression model
model = LinearRegression()

# %%
#8. fit the model
# Train the model on the training set
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#9.predict the output
y_pred=model.predict(X_test )#using input test data,we predict
y_pred #predicted o/p values
# Out:
# array([ -86.59813878, 1063.55036977,  879.36907442, 1364.51948709,
#         242.88829021,  377.98871283,  718.28012333, 1198.18049185,
#         587.76193916,   22.81389203, 1478.81743699,  523.06117834,
#         915.29885975, 1206.15327648,  937.9625522 ,  711.45002593,
#         940.87543997])

# %%
y_test
# Out:
# 78     328.0
# 0      240.0
# 68     150.0
# 22    2208.0
# 12     444.0
# 82     441.0
# 10     562.0
# 18    1666.0
# 4      663.0
# 66     256.0
# 40     308.0
# 47     547.0
# 35     708.0
# 72     206.0
# 55    1563.0
# 54    1668.0
# 33     627.0
# Name: Distance, dtype: float64

# %%
#conclusion
# we have to compare corresponding values of y_pred and y
#50 when we compare,we come to know that there is huge difference
#this huge difference does not mean,our model has predicted wrong
#it only means our model is not linear or lesslinear
#linearity of  a model depends on nature of the data
#as well as size of the data

# %%
#10.#individual prediction

a=df['Origin'][10]
a
# Out:
# 'Bengaluru'

# %%
b=df['Destination'][10]
b
# Out:
# 'Goa'

# %%
#streamlit (web app)
#let us create our first streamlit webapp
#the streamlit library is not intalled default by google colab
#hence we have to install it manually
# !pip install streamlit --quiet

# %%
# %%writefile distance.py
import streamlit as st


data = {
       'Agra-Delhi': 240,
       'Agra-Lucknow': 334,
       'Agra-Kanpur':526,
       'Ahmedabad-Mumbai':663,
       'Ahmedabad-Pune':660,
       'Ahmedabad-Jaipur':258,
       'Ahmedabad-Udaipur':839,
       'Bengaluru-Pune':576,
       'Bengaluru-Hyderabad':346,
       'Bengaluru-Chennai':562,
       'Bengaluru-Goa':442,
       'Bhubaneswar-Kolkata':444,
       'Bhubaneswar-Vishakhapatnam':831,
       'Bhubaneswar-Patna':626,
       'Chennai-Hyderabad':345,
       'Chennai-Bengaluru':690,
       'Chennai-Kochi':1335,
       'Chennai-Mumbai':1666,
       'Chennai-Kolkata':307,
       'Delhi-Jaipur':243,
       'Delhi-Agra':548,
       'Delhi-Lucknow':2208,
       'Delhi-Chennai':2174,
       'Delhi-Bengaluru':1452,
       'Delhi-Mumbai':1582,
       'Delhi-Hyderabad':674,
       'Goa-Hyderabad':755,
       'Goa-Kochi':585,
       'Goa-Mumbai':442,
       'Goa-Pune':1305,
       'Goa-Thiruvananthapuram':562,
       'Hyderabad-Pune':576,
       'Hyderabad-Bengaluru':627,
       'Hyderabad-Chennai':674,
       'Hyderabad-Goa':708,
       'Hyderabad-Mumbai':1583,
       'Hyderabad-Delhi':1489,
       'Hyderabad-Kolkata':659,
       'Jaipur-Ahmedabad':697,
       'Jaipur-Udaipur':308,
       'Jaipur-Delhi':1170,
       'Jaipur-Mumbai':1191,
       'Jaipur-Pune':301,
       'Kanpur-Agra':115,
       'Kanpur-Lucknow':328,
       'Kanpur-Varanasi':690,
       'Kochi-Chennai':547,
       'Kochi-Bengaluru':754,
       'Kochi-Goa':206,
       'Kochi-Thiruvananthapuram':547,
       'Kochi-Bengaluru':680,
       'Kolkata-Varanasi':554,
       'Kolkata-Patna':442,
       'Kolkata-Bhubaneswar':1668,
       'Kolkata-Chennai':1563,
       'Kolkata-Delhi':553,
       'Lucknow-Delhi':333,
       'Lucknow-Agra':89,
       'Lucknow-Kanpur':148,
       'Mumbai-Pune':526,
       'Mumbai-Ahmedabad':1453,
       'Mumbai-Delhi':713,
       'Mumbai-Hyderabad':984,
       'Mumbai-Bengaluru':1886,
       'Mumbai-Kolkata':1338,
       'Mumbai-Chennai':256,
       'Patna-Varanasi':578,
       'Patna-Kolkata':150,
       'Pune-Mumbai':560,
       'Pune-Ahmedabad':842,
       'Pune-Hyderabad':257,
       'Pune-Bengaluru':767,
       'Udaipur-Ahmedabad':688,
       'Udaipur-Jaipur':259,
       'Udaipur-Mumbai':683,
       'Udaipur-Delhi':312,
       'Varanasi-Kanpur':456,
       'Varanasi-Patna':683,
       'Varanasi-Kolkata':312,
       'Varanasi-Lucknow':441,
       'Vishakhapatnam-Bhubaneswar':618,
       'Vishakhapatnam-Hyderabad':882,
       'Vishakhapatnam-Kolkata':567

}

# Streamlit app
st.title('Distance Calculator App')

# Create a dropdown for origin and destination
origin = st.selectbox('Select Origin', list(set([x.split('-')[0] for x in data.keys()])))
destination = st.selectbox('Select Destination', list(set([x.split('-')[1] for x in data.keys()])))

# Display the distance
key = f'{origin}-{destination}'
if key in data:
    distance = data[key]
    st.write(f'Distance from {origin} to {destination}: {distance} km')
else:
    st.write(f'Distance from {origin} to {destination} not available')
# Out:
# Overwriting distance.py

# %%
#we have to execute distance.py using localtunnel
# !streamlit run distance.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.119.35:8501
#
# your url is: https://fine-worlds-crash.loca.lt
#   Stopping...
# ^C

# %% [markdown]
# # New Section
